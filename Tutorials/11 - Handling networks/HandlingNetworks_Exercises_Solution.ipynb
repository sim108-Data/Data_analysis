# %%
import numpy as np
import pandas as pd
import networkx as nx

# %% [markdown]
# # Handling Networks

# %% [markdown]
# <img src="imgs/sheldon.gif">

# %% [markdown]
# ### Let's continue our exploration of the show Big Bang Theory with a focus on it's graph structure!
#
# First, load the data that we prepared for you the data in a nice format:

# %%
lines = pd.read_pickle("data/BBT_lines.pkl")
lines.head()
# Out:
#    Season                               Episode                        Scene  \
# 0       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
# 1       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
# 2       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
# 3       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
# 4       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
#
#       Character                                               Line
# 0       Sheldon  So if a photon is directed through a plane wit...
# 1       Leonard                         Agreed, what’s your point?
# 2       Sheldon  There’s no point, I just think it’s a good ide...
# 3       Leonard                                         Excuse me?
# 4  Receptionist                                           Hang on.

# %% [markdown]
# And let's define the characters that we are interested to study:

# %%
recurrent_characters = ['Amy', 'Arthur', 'Bernadette', 'Bert', 'Beverley', 'Emily', 'Howard', 
                       'Leonard', 'Leslie', 'Penny', 'Priya', 'Raj', 'Sheldon', 'Stuart', 'Wil', 
                       'Zack', 'Lucy', 'Kripke', 'Isabella']

# %% [markdown]
# ## The Gossip Graph
#
# Let us define _gossip_ as follows: if a dialogue line of character A mentions B by name in a scene that does not involve character B, we say that “A gossips about B” in that line. Multiple mentions of the same person in a single line are counted once, but a character can gossip about several others in the same line. For the sake of simplicity, we only consider gossips where the name of the recurrent character is mentioned as it appears in our list of characters; for example, if someone says "Cooper" and they mean Sheldon, we discard that.
#
# Create the two following graphs first:
#
# 1. Create the _familiarity graph_, an undirected weighted graph, in which there is a node for each recurrent character, and an edge between two characters if they appear together in at least one scene. The weight of the edge between them is the number of scenes they appear in together. If an edge exists between two people in the familiarity graph, we say that they "know each other".
# 2. Create the _gossip graph_, which is a directed weighted graph, in which there there is a node for each recurrent character, and a directed edge from the node for A to the node for B if A has gossiped about B at least once. The weight of the edge is the number of scenes in which A has gossiped about B.
#
# Visualise both graphs.

# %% [markdown]
# Keep only the lines of the recurrent character:

# %%
lines_filtered = lines[lines["Character"].isin(recurrent_characters)]
lines_filtered.head()
# Out:
#    Season                               Episode                        Scene  \
# 0       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
# 1       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
# 2       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
# 3       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
# 5       1  Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.
#
#   Character                                               Line
# 0   Sheldon  So if a photon is directed through a plane wit...
# 1   Leonard                         Agreed, what’s your point?
# 2   Sheldon  There’s no point, I just think it’s a good ide...
# 3   Leonard                                         Excuse me?
# 5   Leonard  One across is Aegean, eight down is Nabakov, t...

# %% [markdown]
# Create all the sets of people in the same scene:

# %%
import re

def get_gossip(scene_lines):
    in_scene_characters = set(scene_lines["Character"])
    # {Penny, Leonard, Sheldon, Howard}
    return in_scene_characters

in_same_scene = lines_filtered.groupby(["Season", "Episode", "Scene"]).apply(get_gossip)
in_same_scene.head()
# Out:
# <<<<<<< local
# Season  Episode                               Scene
# 1       Series 01 Episode 01 – Pilot Episode  A corridor at a sperm bank.                                    {Leonard, Sheldon}
#                                               All five in Leonard’s car.                      {Leonard, Howard, Penny, Sheldon}
#                                               Back at the apartment.                                            {Howard, Penny}
#                                               In the bathroom.                                                 {Leonard, Penny}
#                                               Inside Sheldon and Leonard’s apartment.    {Howard, Penny, Leonard, Raj, Sheldon}
# dtype: object
# =======
# >>>>>>> remote
# <<<<<<< local <removed>
# =======
# 0                        {Leonard, Sheldon}
# 1         {Sheldon, Leonard, Howard, Penny}
# 2                           {Howard, Penny}
# 3                          {Leonard, Penny}
# 4    {Sheldon, Leonard, Howard, Raj, Penny}
# dtype: object
# >>>>>>> remote <modified: text/plain>

# %%
in_same_scene=in_same_scene.reset_index(drop=True) # drop egal true enleve les index ouf
in_same_scene.head()
# Out:
# 0                        {Leonard, Sheldon}
# 1         {Leonard, Howard, Penny, Sheldon}
# 2                           {Howard, Penny}
# 3                          {Leonard, Penny}
# 4    {Howard, Penny, Leonard, Raj, Sheldon}
# dtype: object

# %% [markdown]
# Familiarity graph:

# %%
import collections

# Example with Counter
pairs = []
for idx, values in in_same_scene.iteritems():
    print('-----------------------------------------',idx)
    print(values) ## Stop 1
    characters = list(values)
    print(characters)  ## Stop 2
    while len(characters)>0:
        print(len(characters))  ## Stop 3
        current = characters.pop(0)
        print(current,':current')
        print(characters,"reste du character observer Si vide ça s'arrete")
        for c in characters:
            print(c)  ## Stop  4
            pairs.append(tuple(sorted([current, c])))
            print(pairs)  ## Stop 5
            print('-----------------------')
    print('-------------------------------------------- Stop')
    break
common_scenes = collections.Counter(pairs)
# Out:
# ----------------------------------------- 0
# {'Leonard', 'Sheldon'}
# ['Leonard', 'Sheldon']
# 2
# Leonard :current
# ['Sheldon'] reste du character observer Si vide ça s'arrete
# Sheldon
# [('Leonard', 'Sheldon')]
# -----------------------
# 1
# Sheldon :current
# [] reste du character observer Si vide ça s'arrete
# -------------------------------------------- Stop

# %%
import collections

# Example with Counter
pairs = []
for idx, values in in_same_scene.iteritems():
    
    characters = list(values)
    while len(characters)>0:
        current = characters.pop(0)
        for c in characters:
            pairs.append(tuple(sorted([current, c])))
common_scenes = collections.Counter(pairs)

# %%
common_scenes
# Out:
# Counter({('Leonard', 'Sheldon'): 870,
#          ('Howard', 'Leonard'): 572,
#          ('Leonard', 'Penny'): 614,
#          ('Howard', 'Penny'): 303,
#          ('Howard', 'Sheldon'): 538,
#          ('Penny', 'Sheldon'): 583,
#          ('Howard', 'Raj'): 600,
#          ('Penny', 'Raj'): 266,
#          ('Leonard', 'Raj'): 520,
#          ('Raj', 'Sheldon'): 493,
#          ('Howard', 'Leslie'): 11,
#          ('Leslie', 'Penny'): 5,
#          ('Leonard', 'Leslie'): 14,
#          ('Leslie', 'Raj'): 9,
#          ('Leslie', 'Sheldon'): 15,
#          ('Kripke', 'Leonard'): 14,
#          ('Kripke', 'Raj'): 12,
#          ('Kripke', 'Sheldon'): 18,
#          ('Howard', 'Kripke'): 9,
#          ('Kripke', 'Penny'): 1,
#          ('Beverley', 'Leonard'): 14,
#          ('Beverley', 'Sheldon'): 11,
#          ('Beverley', 'Penny'): 13,
#          ('Beverley', 'Howard'): 6,
#          ('Beverley', 'Raj'): 4,
#          ('Sheldon', 'Stuart'): 68,
#          ('Howard', 'Stuart'): 83,
#          ('Penny', 'Stuart'): 40,
#          ('Leonard', 'Stuart'): 56,
#          ('Raj', 'Stuart'): 79,
#          ('Bernadette', 'Leonard'): 144,
#          ('Bernadette', 'Howard'): 281,
#          ('Bernadette', 'Penny'): 223,
#          ('Bernadette', 'Sheldon'): 137,
#          ('Howard', 'Wil'): 8,
#          ('Penny', 'Wil'): 8,
#          ('Leonard', 'Wil'): 15,
#          ('Raj', 'Wil'): 11,
#          ('Sheldon', 'Wil'): 13,
#          ('Stuart', 'Wil'): 6,
#          ('Amy', 'Raj'): 140,
#          ('Amy', 'Sheldon'): 335,
#          ('Amy', 'Howard'): 129,
#          ('Leonard', 'Zack'): 15,
#          ('Penny', 'Zack'): 17,
#          ('Howard', 'Zack'): 12,
#          ('Sheldon', 'Zack'): 15,
#          ('Amy', 'Penny'): 307,
#          ('Amy', 'Leonard'): 228,
#          ('Bernadette', 'Raj'): 184,
#          ('Leonard', 'Priya'): 31,
#          ('Priya', 'Sheldon'): 23,
#          ('Howard', 'Priya'): 18,
#          ('Priya', 'Raj'): 18,
#          ('Amy', 'Bernadette'): 196,
#          ('Amy', 'Zack'): 5,
#          ('Bernadette', 'Zack'): 4,
#          ('Raj', 'Zack'): 8,
#          ('Stuart', 'Zack'): 4,
#          ('Penny', 'Priya'): 12,
#          ('Bernadette', 'Priya'): 10,
#          ('Amy', 'Priya'): 3,
#          ('Amy', 'Stuart'): 35,
#          ('Kripke', 'Wil'): 2,
#          ('Kripke', 'Stuart'): 2,
#          ('Bernadette', 'Stuart'): 54,
#          ('Amy', 'Wil'): 4,
#          ('Lucy', 'Raj'): 10,
#          ('Howard', 'Lucy'): 2,
#          ('Arthur', 'Sheldon'): 10,
#          ('Arthur', 'Leonard'): 5,
#          ('Arthur', 'Penny'): 2,
#          ('Amy', 'Lucy'): 2,
#          ('Lucy', 'Penny'): 2,
#          ('Arthur', 'Howard'): 1,
#          ('Amy', 'Arthur'): 2,
#          ('Arthur', 'Raj'): 1,
#          ('Bernadette', 'Lucy'): 1,
#          ('Bert', 'Howard'): 6,
#          ('Amy', 'Bert'): 8,
#          ('Bert', 'Raj'): 7,
#          ('Emily', 'Raj'): 32,
#          ('Amy', 'Emily'): 7,
#          ('Emily', 'Penny'): 8,
#          ('Emily', 'Leonard'): 8,
#          ('Emily', 'Wil'): 1,
#          ('Emily', 'Howard'): 13,
#          ('Bernadette', 'Emily'): 13,
#          ('Emily', 'Sheldon'): 7,
#          ('Emily', 'Stuart'): 3,
#          ('Amy', 'Kripke'): 1,
#          ('Beverley', 'Leslie'): 1,
#          ('Leslie', 'Wil'): 1,
#          ('Bernadette', 'Leslie'): 1,
#          ('Amy', 'Leslie'): 1,
#          ('Leslie', 'Stuart'): 1,
#          ('Beverley', 'Wil'): 1,
#          ('Bernadette', 'Beverley'): 4,
#          ('Amy', 'Beverley'): 5,
#          ('Beverley', 'Stuart'): 3,
#          ('Bernadette', 'Wil'): 1,
#          ('Bert', 'Penny'): 4,
#          ('Bert', 'Leonard'): 7,
#          ('Bert', 'Sheldon'): 10,
#          ('Bert', 'Stuart'): 1,
#          ('Isabella', 'Raj'): 2,
#          ('Howard', 'Isabella'): 1,
#          ('Emily', 'Lucy'): 1})

# %%
for key in common_scenes:
    print(key)
    print(common_scenes[key])
    break
# Out:
# ('Leonard', 'Sheldon')
# 870

# %%
familiarity_graph = nx.Graph()

for key in common_scenes:
    familiarity_graph.add_edge(key[0], key[1], weight=common_scenes[key])

edges = familiarity_graph.edges()
weights = [0.01*familiarity_graph[u][v]['weight'] for u,v in edges]

nx.draw_shell(familiarity_graph, with_labels=True, alpha = 0.6, node_size=1000, width=weights)

# %% [markdown]
# ----
#
# Gossip graph:

# %%
import re

def get_gossip(scene_lines):
    gossip_mentions = []
    # Characters speaking in the current scene
    in_scene_characters = set(scene_lines["Character"])
    for idx, row in scene_lines.iterrows():
        # split where is not a letter
        line_words = re.split("[^a-zA-Z]+", row["Line"])
        # Token is in the list of characters and not in the current scene
        #print(line_words)
        gossip = [c for c in line_words if c in recurrent_characters and c not in in_scene_characters]
        if len(gossip)>0:
            gossip_mentions.append([{"Character": row["Character"], "Mention": c} for c in gossip])
    # Example: [[{'Character': 'Penny', 'Mentions': 'Raj'}], ...]
    return gossip_mentions

gm = lines_filtered.groupby(["Season", "Episode", "Scene"]).apply(get_gossip)
gm.reset_index()
# Out:
#       Season                                            Episode  \
# 0          1               Series 01 Episode 01 – Pilot Episode
# 1          1               Series 01 Episode 01 – Pilot Episode
# 2          1               Series 01 Episode 01 – Pilot Episode
# 3          1               Series 01 Episode 01 – Pilot Episode
# 4          1               Series 01 Episode 01 – Pilot Episode
# ...      ...                                                ...
# 1938      10  Series 10 Episode 24 – The Long Distance Disso...
# 1939      10  Series 10 Episode 24 – The Long Distance Disso...
# 1940      10  Series 10 Episode 24 – The Long Distance Disso...
# 1941      10  Series 10 Episode 24 – The Long Distance Disso...
# 1942      10  Series 10 Episode 24 – The Long Distance Disso...
#
#                                         Scene  \
# 0                 A corridor at a sperm bank.
# 1                  All five in Leonard’s car.
# 2                      Back at the apartment.
# 3                            In the bathroom.
# 4     Inside Sheldon and Leonard’s apartment.
# ...                                       ...
# 1938                           The apartment.
# 1939                           The cafeteria.
# 1940                    The comic book store.
# 1941                         The same, later.
# 1942                              The street.
#
#                                                       0
# 0                                                    []
# 1          [[{'Character': 'Penny', 'Mention': 'Raj'}]]
# 2     [[{'Character': 'Penny', 'Mention': 'Leonard'}...
# 3     [[{'Character': 'Leonard', 'Mention': 'Sheldon...
# 4                                                    []
# ...                                                 ...
# 1938                                                 []
# 1939  [[{'Character': 'Howard', 'Mention': 'Amy'}], ...
# 1940  [[{'Character': 'Howard', 'Mention': 'Sheldon'...
# 1941  [[{'Character': 'Penny', 'Mention': 'Amy'}], [...
# 1942  [[{'Character': 'Sheldon', 'Mention': 'Leonard...
#
# [1943 rows x 4 columns]

# %%
gm=gm.reset_index(drop=True)
gm
# Out:
# 0                                                      []
# 1            [[{'Character': 'Penny', 'Mention': 'Raj'}]]
# 2       [[{'Character': 'Penny', 'Mention': 'Leonard'}...
# 3       [[{'Character': 'Leonard', 'Mention': 'Sheldon...
# 4                                                      []
#                               ...
# 1938                                                   []
# 1939    [[{'Character': 'Howard', 'Mention': 'Amy'}], ...
# 1940    [[{'Character': 'Howard', 'Mention': 'Sheldon'...
# 1941    [[{'Character': 'Penny', 'Mention': 'Amy'}], [...
# 1942    [[{'Character': 'Sheldon', 'Mention': 'Leonard...
# Length: 1943, dtype: object

# %%
all_mentions = []
for idx, values in gm.iteritems():
    for mentions in values:
        print(mentions)
        all_mentions += mentions
all_mentions = pd.DataFrame(all_mentions)
all_mentions.head()
# Out:
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}, {'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}, {'Character': 'Penny', 'Mention': 'Howard'}, {'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Raj', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}, {'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leslie'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Leslie'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Leslie'}]
# [{'Character': 'Leslie', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Sheldon'}, {'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Leslie'}]
# [{'Character': 'Raj', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}, {'Character': 'Leonard', 'Mention': 'Beverley'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}, {'Character': 'Howard', 'Mention': 'Raj'}, {'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Leslie'}]
# [{'Character': 'Howard', 'Mention': 'Leslie'}]
# [{'Character': 'Sheldon', 'Mention': 'Leslie'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Howard'}, {'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Stuart', 'Mention': 'Penny'}, {'Character': 'Stuart', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Leslie'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Leslie'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Howard', 'Mention': 'Leslie'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}, {'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Stuart'}]
# [{'Character': 'Stuart', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Stuart', 'Mention': 'Penny'}]
# [{'Character': 'Stuart', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Stuart', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Stuart'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}, {'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}, {'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Bert'}]
# [{'Character': 'Leonard', 'Mention': 'Bert'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Wil'}, {'Character': 'Raj', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Stuart', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Raj', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Raj', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Raj', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}, {'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}, {'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Kripke'}]
# [{'Character': 'Leonard', 'Mention': 'Kripke'}]
# [{'Character': 'Leonard', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Bernadette', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Beverley', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}, {'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Howard', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}, {'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Zack'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}, {'Character': 'Howard', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}, {'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Bernadette'}, {'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}, {'Character': 'Howard', 'Mention': 'Bernadette'}, {'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Priya', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}, {'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}, {'Character': 'Sheldon', 'Mention': 'Priya'}, {'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Sheldon', 'Mention': 'Priya'}]
# [{'Character': 'Priya', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}, {'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}, {'Character': 'Amy', 'Mention': 'Bernadette'}, {'Character': 'Amy', 'Mention': 'Penny'}, {'Character': 'Amy', 'Mention': 'Zack'}]
# [{'Character': 'Amy', 'Mention': 'Zack'}]
# [{'Character': 'Amy', 'Mention': 'Zack'}]
# [{'Character': 'Sheldon', 'Mention': 'Zack'}]
# [{'Character': 'Sheldon', 'Mention': 'Zack'}]
# [{'Character': 'Amy', 'Mention': 'Zack'}]
# [{'Character': 'Sheldon', 'Mention': 'Zack'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}, {'Character': 'Amy', 'Mention': 'Zack'}]
# [{'Character': 'Sheldon', 'Mention': 'Zack'}, {'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Zack'}, {'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Zack'}, {'Character': 'Sheldon', 'Mention': 'Amy'}, {'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}, {'Character': 'Leonard', 'Mention': 'Zack'}]
# [{'Character': 'Sheldon', 'Mention': 'Zack'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Bernadette', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}, {'Character': 'Penny', 'Mention': 'Bernadette'}, {'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}, {'Character': 'Sheldon', 'Mention': 'Bernadette'}, {'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Amy'}, {'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}, {'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Amy', 'Mention': 'Priya'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}, {'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}, {'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Amy', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Priya'}, {'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}, {'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Priya', 'Mention': 'Penny'}]
# [{'Character': 'Priya', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Raj', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}, {'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Priya'}]
# [{'Character': 'Amy', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Amy', 'Mention': 'Howard'}, {'Character': 'Amy', 'Mention': 'Bernadette'}]
# [{'Character': 'Amy', 'Mention': 'Bernadette'}, {'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}, {'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Bernadette'}]
# [{'Character': 'Raj', 'Mention': 'Bernadette'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}, {'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}, {'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Bernadette'}, {'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Priya', 'Mention': 'Bernadette'}, {'Character': 'Priya', 'Mention': 'Howard'}]
# [{'Character': 'Priya', 'Mention': 'Bernadette'}]
# [{'Character': 'Priya', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}, {'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}, {'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}, {'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}, {'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}, {'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Bernadette', 'Mention': 'Priya'}]
# [{'Character': 'Sheldon', 'Mention': 'Priya'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}, {'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Bernadette', 'Mention': 'Priya'}, {'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Priya'}]
# [{'Character': 'Amy', 'Mention': 'Priya'}, {'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Priya'}, {'Character': 'Amy', 'Mention': 'Leonard'}, {'Character': 'Amy', 'Mention': 'Priya'}]
# [{'Character': 'Amy', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}, {'Character': 'Bernadette', 'Mention': 'Priya'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Raj', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Raj', 'Mention': 'Sheldon'}, {'Character': 'Raj', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Amy', 'Mention': 'Bernadette'}]
# [{'Character': 'Raj', 'Mention': 'Leonard'}]
# [{'Character': 'Raj', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Priya'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Priya'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Raj', 'Mention': 'Sheldon'}, {'Character': 'Raj', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}, {'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Emily'}]
# [{'Character': 'Howard', 'Mention': 'Emily'}]
# [{'Character': 'Raj', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Emily'}]
# [{'Character': 'Howard', 'Mention': 'Emily'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Amy', 'Mention': 'Wil'}]
# [{'Character': 'Penny', 'Mention': 'Wil'}]
# [{'Character': 'Amy', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}, {'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Leonard', 'Mention': 'Wil'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Raj', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}, {'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Penny', 'Mention': 'Priya'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Priya'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}, {'Character': 'Amy', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}, {'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}, {'Character': 'Sheldon', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Bernadette', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}, {'Character': 'Penny', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}, {'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}, {'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}, {'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}, {'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Kripke'}]
# [{'Character': 'Howard', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Stuart'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Stuart', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Stuart', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}, {'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}, {'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}, {'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Raj'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}, {'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}, {'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Wil'}, {'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Raj', 'Mention': 'Leonard'}]
# [{'Character': 'Raj', 'Mention': 'Sheldon'}]
# [{'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}, {'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}, {'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}, {'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Howard'}, {'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}, {'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Raj', 'Mention': 'Leonard'}]
# [{'Character': 'Raj', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}, {'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Amy', 'Mention': 'Kripke'}]
# [{'Character': 'Leonard', 'Mention': 'Kripke'}]
# [{'Character': 'Leonard', 'Mention': 'Kripke'}]
# [{'Character': 'Penny', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Raj', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# ...
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Stuart'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Emily'}]
# [{'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Amy'}]
# [{'Character': 'Raj', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Bernadette', 'Mention': 'Stuart'}]
# [{'Character': 'Amy', 'Mention': 'Kripke'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Kripke'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Raj', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Leonard', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}, {'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Arthur', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Raj', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Stuart'}]
# [{'Character': 'Bernadette', 'Mention': 'Stuart'}]
# [{'Character': 'Howard', 'Mention': 'Stuart'}]
# [{'Character': 'Sheldon', 'Mention': 'Emily'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}]
# [{'Character': 'Howard', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Bernadette', 'Mention': 'Emily'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Howard', 'Mention': 'Emily'}]
# [{'Character': 'Bernadette', 'Mention': 'Emily'}]
# [{'Character': 'Howard', 'Mention': 'Emily'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Emily'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Raj', 'Mention': 'Kripke'}]
# [{'Character': 'Amy', 'Mention': 'Kripke'}]
# [{'Character': 'Amy', 'Mention': 'Kripke'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Amy', 'Mention': 'Kripke'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Howard', 'Mention': 'Emily'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}, {'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Raj', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Wil'}]
# [{'Character': 'Penny', 'Mention': 'Raj'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Bernadette', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Bernadette', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Stuart', 'Mention': 'Howard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Amy'}, {'Character': 'Sheldon', 'Mention': 'Howard'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Stuart', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Raj'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Emily'}]
# [{'Character': 'Leonard', 'Mention': 'Emily'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}, {'Character': 'Amy', 'Mention': 'Bernadette'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Stuart', 'Mention': 'Sheldon'}]
# [{'Character': 'Stuart', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Stuart', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Amy', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Bert', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}, {'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Stuart'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Bernadette'}]
# [{'Character': 'Stuart', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Isabella'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Raj', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Bert'}]
# [{'Character': 'Amy', 'Mention': 'Bert'}]
# [{'Character': 'Amy', 'Mention': 'Bert'}]
# [{'Character': 'Sheldon', 'Mention': 'Bert'}]
# [{'Character': 'Penny', 'Mention': 'Bert'}]
# [{'Character': 'Leonard', 'Mention': 'Bert'}]
# [{'Character': 'Amy', 'Mention': 'Bert'}]
# [{'Character': 'Penny', 'Mention': 'Bert'}]
# [{'Character': 'Sheldon', 'Mention': 'Bert'}, {'Character': 'Sheldon', 'Mention': 'Bert'}, {'Character': 'Sheldon', 'Mention': 'Bert'}]
# [{'Character': 'Amy', 'Mention': 'Bert'}]
# [{'Character': 'Stuart', 'Mention': 'Howard'}, {'Character': 'Stuart', 'Mention': 'Bernadette'}]
# [{'Character': 'Amy', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}, {'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Raj', 'Mention': 'Bernadette'}, {'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Stuart'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}, {'Character': 'Raj', 'Mention': 'Bernadette'}]
# [{'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Bernadette'}]
# [{'Character': 'Amy', 'Mention': 'Bernadette'}]
# [{'Character': 'Amy', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Wil'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Bernadette', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Emily'}]
# [{'Character': 'Bernadette', 'Mention': 'Emily'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Stuart'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}, {'Character': 'Amy', 'Mention': 'Penny'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}]
# [{'Character': 'Bernadette', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Howard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}]
# [{'Character': 'Leonard', 'Mention': 'Stuart'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Howard'}, {'Character': 'Sheldon', 'Mention': 'Raj'}, {'Character': 'Sheldon', 'Mention': 'Kripke'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Leonard'}, {'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Sheldon'}, {'Character': 'Raj', 'Mention': 'Leonard'}, {'Character': 'Raj', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Stuart'}, {'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Beverley'}]
# [{'Character': 'Sheldon', 'Mention': 'Penny'}, {'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Stuart'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Bernadette', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Raj', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Howard'}, {'Character': 'Penny', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Leonard', 'Mention': 'Howard'}]
# [{'Character': 'Zack', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Zack'}, {'Character': 'Penny', 'Mention': 'Leonard'}]
# [{'Character': 'Bernadette', 'Mention': 'Leonard'}]
# [{'Character': 'Penny', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Zack'}]
# [{'Character': 'Penny', 'Mention': 'Zack'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}, {'Character': 'Sheldon', 'Mention': 'Bernadette'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Amy', 'Mention': 'Bernadette'}]
# [{'Character': 'Leonard', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Amy', 'Mention': 'Sheldon'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Howard'}]
# [{'Character': 'Raj', 'Mention': 'Bert'}]
# [{'Character': 'Bernadette', 'Mention': 'Bert'}]
# [{'Character': 'Howard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}, {'Character': 'Sheldon', 'Mention': 'Amy'}, {'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Raj'}]
# [{'Character': 'Amy', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}]
# [{'Character': 'Howard', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Howard', 'Mention': 'Bernadette'}]
# [{'Character': 'Howard', 'Mention': 'Sheldon'}]
# [{'Character': 'Leonard', 'Mention': 'Penny'}]
# [{'Character': 'Raj', 'Mention': 'Sheldon'}]
# [{'Character': 'Penny', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Amy'}]
# [{'Character': 'Leonard', 'Mention': 'Amy'}]
# [{'Character': 'Sheldon', 'Mention': 'Leonard'}, {'Character': 'Sheldon', 'Mention': 'Amy'}]
#   Character  Mention
# 0     Penny      Raj
# 1     Penny  Leonard
# 2     Penny  Sheldon
# 3   Leonard  Sheldon
# 4   Sheldon    Penny

# %%
all_mentions.head()
# Out:
#   Character  Mention
# 0     Penny      Raj
# 1     Penny  Leonard
# 2     Penny  Sheldon
# 3   Leonard  Sheldon
# 4   Sheldon    Penny

# %%
node_weights = all_mentions.value_counts(["Character", "Mention"])
node_weights
# Out:
# Character  Mention
# Penny      Leonard    135
# Sheldon    Leonard    132
#            Amy        105
# Leonard    Penny      105
# Sheldon    Penny       72
#                      ...
# Howard     Lucy         1
#            Kripke       1
# Emily      Raj          1
#            Leonard      1
# Amy        Arthur       1
# Length: 119, dtype: int64

# %%
node_weights = node_weights.reset_index()
node_weights
# Out:
#     Character  Mention    0
# 0       Penny  Leonard  135
# 1     Sheldon  Leonard  132
# 2     Sheldon      Amy  105
# 3     Leonard    Penny  105
# 4     Sheldon    Penny   72
# ..        ...      ...  ...
# 114    Howard     Lucy    1
# 115    Howard   Kripke    1
# 116     Emily      Raj    1
# 117     Emily  Leonard    1
# 118       Amy   Arthur    1
#
# [119 rows x 3 columns]

# %%
node_weights.columns = ["Character", "Mention", "weight"]
node_weights.groupby(['Mention']).sum().sort_values('weight',ascending=False).head(1)
# Out:
#          weight
# Mention
# Leonard     340

# %%
gossip_graph = nx.DiGraph()

for idx, r in node_weights.iterrows():
    gossip_graph.add_edge(r["Character"], r["Mention"], weight=r["weight"])
    
weighted_degree = dict(gossip_graph.degree(weight='weight'))

edges = gossip_graph.edges()
weights = [0.005*gossip_graph[u][v]['weight'] for u,v in edges]

nx.draw_shell(gossip_graph, with_labels=True, alpha = 0.6, width=weights,
              node_size=[v * 3 for v in weighted_degree.values()])
# Out:
# <<<<<<< local
# =======
# >>>>>>> remote

# %% [markdown]
# Now, answer the following questions:
#
# **Q1: Who is the most mentioned person?**

# %%
node_weights.groupby(['Mention']).sum().sort_values('weight',ascending=False).head(1)
# Out:
#          weight
# Mention
# Leonard     340

# %%
import collections

weighted_degree = collections.Counter(dict(gossip_graph.in_degree(weight='weight')))
weighted_degree.most_common()[0]
# Out:
# ('Leonard', 340)

# %% [markdown]
# **Q2: Sheldon claims that every character in the show is familiar with everyone else through at most one intermediary. Based on the familiarity graph, is this true? If not, at most how many intermediaries are needed?**

# %%
nodes = list(familiarity_graph.nodes)

one_intermediary = True
for source_idx in range(0, len(familiarity_graph.nodes)):
    for destination_idx in range(source_idx+1, len(familiarity_graph.nodes)): # source_idx+1 on le prend pas lui même
        shortest_path = nx.shortest_path_length(familiarity_graph, 
                                                source=nodes[source_idx], 
                                                target=nodes[destination_idx])
        if shortest_path>2:
            one_intermediary = False
            break

print("The claim of Sheldon is {}".format(one_intermediary))
# Out:
# The claim of Sheldon is True

# %% [markdown]
# **Q3. Who is the character through whom the largest number of these indirect familiarities happen? Calculate an appropriate centrality metric on the familiarity graph to answer this question.**

# %%
most_central_people = sorted(nx.betweenness_centrality(familiarity_graph).items(), key=lambda r: -r[1])
most_central_people[:5]
# Out:
# [('Howard', 0.10090777051561366),
#  ('Raj', 0.10090777051561366),
#  ('Penny', 0.04862018881626725),
#  ('Amy', 0.04862018881626725),
#  ('Leonard', 0.03413217138707334)]

# %% [markdown]
# **Q4. Another claim of Sheldon's is that every recurrent character in the show gossips about all the other recurrent characters. (A) Does the gossip graph possess that property?**

# %%
total_characters = len(gossip_graph.nodes)
total_characters
# Out:
# 19

# %%
complete = True
for c in gossip_graph.nodes:
    in_degree = gossip_graph.in_degree(c, weight=None) # in_degree c'est toute les entrées qu'on peut avoir par noeud
    if in_degree < total_characters-1:
        complete = False
        break
        
# Alternative: use out_degree

print("The claim of Sheldon that every recurrent character gossips about all the others is {}".format(complete))
# Out:
# The claim of Sheldon that every recurrent character gossips about all the others is False

# %% [markdown]
# **Q5. Use the gossip graph and the familiarity graph to figure out if for every pair of recurrent characters, one of them has gossiped about the other if and only if they know each other (shared a scene).**

# %%
list(gossip_graph.edges)[0][0]
# Out:
# 'Penny'

# %%
# For every gossip edge, check if familiarity edge exists

for ge in gossip_graph.edges:
    source = ge[0]
    destination = ge[1]
    if not familiarity_graph.has_edge(source, destination):
        print("{} speaks about {} without sharing a scene".format(source, destination))
# Out:
# Bernadette speaks about Bert without sharing a scene

# %% [markdown]
# ## Quiz

# %% [markdown]
# **Question A: Given the following adjacency matrix of a graph:**
#
# <img src="imgs/quizA.png">
#
# 1. A is a directed graph with average in-degree 4/3
# 2. A is an undirected graph with average degree 4/3
# 3. A is a directed graph with average in-degree 1
# 4. A is an undirected graph with average degree 1

# %%
# 1. A is a directed graph with average in-degree 4/3

# %% [markdown]
# **Question B: In a horror scenario, your lost luggage is landing at an airport and being loaded to another random flight and transferred to another airport. This has been going on for months. Given a very large number of iterations, which of the following metrics gives you the probability that your luggage ends up in Geneva airport?**
#
# 1. Closeness centrality
# 2. Page rank
# 3. Betweenness centrality
# 4. Katz similarity

# %%
# 2. Page rank
